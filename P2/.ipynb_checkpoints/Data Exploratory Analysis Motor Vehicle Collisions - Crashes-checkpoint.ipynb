# %% [markdown]
# # Data Exploratory Analysis: Motor Vehicle Collisions - Crashes
#
# Data Provided by: Police Department (NYPD)
#
# Dataset Owner: NYC OpenData
#
# Data Collection: Motor Vehicle Collisions
#
# Database: [Motor Vehicle Collisions - Crashes](https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Crashes/h9gi-nx95)
#
# The Motor Vehicle Collisions crash table contains details on the crash event. Each row represents a crash event. The Motor Vehicle Collisions data tables contain information from all police reported motor vehicle collisions in NYC. The police report (MV104-AN) is required to be filled out for collisions where someone is injured or killed, or where there is at least $1000 worth of damage. It should be noted that the data is preliminary and subject to change when the MV-104AN forms are amended based on revised crash details.For the most accurate, up to date statistics on traffic fatalities, please refer to the NYPD Motor Vehicle Collisions page (updated weekly) or Vision Zero View (updated monthly).

# %% [markdown]
# ### Columns in this Dataset
#
# | Column Name                        | Description                                                                                                                                                       | Type       |
# |-----------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------|
# | CRASH DATE                         | Occurrence date of collision                                                                                                                                      | Date & Time|
# | CRASH TIME                         | Occurrence time of collision                                                                                                                                      | Plain Text |
# | BOROUGH                            | Borough where collision occurred                                                                                                                                  | Plain Text |
# | ZIP CODE                           | Postal code of incident occurrence                                                                                                                               | Plain Text |
# | LATITUDE                           | Latitude coordinate for Global Coordinate System, WGS 1984, decimal degrees (EPSG 4326)                                                                          | Number     |
# | LONGITUDE                          | Longitude coordinate for Global Coordinate System, WGS 1984, decimal degrees (EPSG 4326)                                                                         | Number     |
# | LOCATION                           | Latitude , Longitude pair                                                                                                                                        | Location   |
# | ON STREET NAME                     | Street on which the collision occurred                                                                                                                           | Plain Text |
# | CROSS STREET NAME                  | Nearest cross street to the collision                                                                                                                            | Plain Text |
# | OFF STREET NAME                    | Street address if known                                                                                                                                          | Plain Text |
# | NUMBER OF PERSONS INJURED          | Number of persons injured                                                                                                                                        | Number     |
# | NUMBER OF PERSONS KILLED           | Number of persons killed                                                                                                                                         | Number     |
# | NUMBER OF PEDESTRIANS INJURED      | Number of pedestrians injured                                                                                                                                    | Number     |
# | NUMBER OF PEDESTRIANS KILLED       | Number of pedestrians killed                                                                                                                                     | Number     |
# | NUMBER OF CYCLIST INJURED          | Number of cyclists injured                                                                                                                                       | Number     |
# | NUMBER OF CYCLIST KILLED           | Number of cyclists killed                                                                                                                                        | Number     |
# | NUMBER OF MOTORIST INJURED         | Number of vehicle occupants injured                                                                                                                              | Number     |
# | NUMBER OF MOTORIST KILLED          | Number of vehicle occupants killed                                                                                                                               | Number     |
# | CONTRIBUTING FACTOR VEHICLE 1      | Factors contributing to the collision for designated vehicle                                                                                                      | Plain Text |
# | CONTRIBUTING FACTOR VEHICLE 2      | Factors contributing to the collision for designated vehicle                                                                                                      | Plain Text |
# | CONTRIBUTING FACTOR VEHICLE 3      | Factors contributing to the collision for designated vehicle                                                                                                      | Plain Text |
# | CONTRIBUTING FACTOR VEHICLE 4      | Factors contributing to the collision for designated vehicle                                                                                                      | Plain Text |
# | CONTRIBUTING FACTOR VEHICLE 5      | Factors contributing to the collision for designated vehicle                                                                                                      | Plain Text |
# | COLLISION_ID                       | Unique record code generated by system. Primary Key for Crash table.                                                                                             | Number     |
# | VEHICLE TYPE CODE 1                | Type of vehicle based on the selected vehicle category (ATV, bicycle, car/suv, ebike, escooter, truck/bus, motorcycle, other)                                     | Plain Text |
# | VEHICLE TYPE CODE 2                | Type of vehicle based on the selected vehicle category (ATV, bicycle, car/suv, ebike, escooter, truck/bus, motorcycle, other)                                     | Plain Text |
# | VEHICLE TYPE CODE 3                | Type of vehicle based on the selected vehicle category (ATV, bicycle, car/suv, ebike, escooter, truck/bus, motorcycle, other)                                     | Plain Text |
# | VEHICLE TYPE CODE 4                | Type of vehicle based on the selected vehicle category (ATV, bicycle, car/suv, ebike, escooter, truck/bus, motorcycle, other)                                     | Plain Text |
# | VEHICLE TYPE CODE 5                | Type of vehicle based on the selected vehicle category (ATV, bicycle, car/suv, ebike, escooter, truck/bus, motorcycle, other)                                     | Plain Text |

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/Motor_Vehicle_Collisions_-_Crashes.csv")
df.head()
# Out:
# /var/folders/k2/4pwm8g2x5nv53jx5sr5l010c0000gq/T/ipykernel_3173/764124899.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/Motor_Vehicle_Collisions_-_Crashes.csv")
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                      NaN  ...                    Unspecified
# 1                      NaN  ...                            NaN
# 2                      NaN  ...                    Unspecified
# 3  1211      LORING AVENUE  ...                            NaN
# 4                      NaN  ...                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  VEHICLE TYPE CODE 1  \
# 0                            NaN       4455765                Sedan
# 1                            NaN       4513547                Sedan
# 2                            NaN       4541903                Sedan
# 3                            NaN       4456314                Sedan
# 4                            NaN       4486609                  NaN
#
#    VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4  \
# 0                Sedan                  NaN                 NaN
# 1                  NaN                  NaN                 NaN
# 2        Pick-up Truck                  NaN                 NaN
# 3                  NaN                  NaN                 NaN
# 4                  NaN                  NaN                 NaN
#
#   VEHICLE TYPE CODE 5
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2024478 entries, 0 to 2024477
# Data columns (total 29 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   CRASH DATE                     object
#  1   CRASH TIME                     object
#  2   BOROUGH                        object
#  3   ZIP CODE                       object
#  4   LATITUDE                       float64
#  5   LONGITUDE                      float64
#  6   LOCATION                       object
#  7   ON STREET NAME                 object
#  8   CROSS STREET NAME              object
#  9   OFF STREET NAME                object
#  10  NUMBER OF PERSONS INJURED      float64
#  11  NUMBER OF PERSONS KILLED       float64
#  12  NUMBER OF PEDESTRIANS INJURED  int64
#  13  NUMBER OF PEDESTRIANS KILLED   int64
#  14  NUMBER OF CYCLIST INJURED      int64
#  15  NUMBER OF CYCLIST KILLED       int64
#  16  NUMBER OF MOTORIST INJURED     int64
#  17  NUMBER OF MOTORIST KILLED      int64
#  18  CONTRIBUTING FACTOR VEHICLE 1  object
#  19  CONTRIBUTING FACTOR VEHICLE 2  object
#  20  CONTRIBUTING FACTOR VEHICLE 3  object
#  21  CONTRIBUTING FACTOR VEHICLE 4  object
#  22  CONTRIBUTING FACTOR VEHICLE 5  object
#  23  COLLISION_ID                   int64
#  24  VEHICLE TYPE CODE 1            object
#  25  VEHICLE TYPE CODE 2            object
#  26  VEHICLE TYPE CODE 3            object
#  27  VEHICLE TYPE CODE 4            object
#  28  VEHICLE TYPE CODE 5            object
# dtypes: float64(4), int64(7), object(18)
# memory usage: 447.9+ MB

# %%
df.count()
# Out:
# CRASH DATE                       2024478
# CRASH TIME                       2024478
# BOROUGH                          1394696
# ZIP CODE                         1394457
# LATITUDE                         1794331
# LONGITUDE                        1794331
# LOCATION                         1794331
# ON STREET NAME                   1597876
# CROSS STREET NAME                1265717
# OFF STREET NAME                   334229
# NUMBER OF PERSONS INJURED        2024460
# NUMBER OF PERSONS KILLED         2024447
# NUMBER OF PEDESTRIANS INJURED    2024478
# NUMBER OF PEDESTRIANS KILLED     2024478
# NUMBER OF CYCLIST INJURED        2024478
# NUMBER OF CYCLIST KILLED         2024478
# NUMBER OF MOTORIST INJURED       2024478
# NUMBER OF MOTORIST KILLED        2024478
# CONTRIBUTING FACTOR VEHICLE 1    2018097
# CONTRIBUTING FACTOR VEHICLE 2    1715259
# CONTRIBUTING FACTOR VEHICLE 3     143734
# CONTRIBUTING FACTOR VEHICLE 4      32273
# CONTRIBUTING FACTOR VEHICLE 5       8722
# COLLISION_ID                     2024478
# VEHICLE TYPE CODE 1              2011726
# VEHICLE TYPE CODE 2              1645534
# VEHICLE TYPE CODE 3               138698
# VEHICLE TYPE CODE 4                31194
# VEHICLE TYPE CODE 5                 8457
# dtype: int64

# %%
df.dropna(subset=['LONGITUDE', 'LATITUDE'], inplace=True)

# %%
df['CRASH DATE'].min()
# Out:
# '01/01/2013'

# %%
df['CRASH DATE'].max()
# Out:
# '12/31/2022'

# %%
df.describe()
# Out:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  1.794331e+06  1.794331e+06               1.794315e+06
# mean   4.062782e+01 -7.375237e+01               3.044337e-01
# std    1.980282e+00  3.726061e+00               6.913186e-01
# min    0.000000e+00 -2.013600e+02               0.000000e+00
# 25%    4.066792e+01 -7.397492e+01               0.000000e+00
# 50%    4.072098e+01 -7.392732e+01               0.000000e+00
# 75%    4.076956e+01 -7.386667e+01               0.000000e+00
# max    4.334444e+01  0.000000e+00               4.300000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              1.794303e+06                   1.794331e+06
# mean               1.423951e-03                   5.788787e-02
# std                3.990569e-02                   2.469108e-01
# min                0.000000e+00                   0.000000e+00
# 25%                0.000000e+00                   0.000000e+00
# 50%                0.000000e+00                   0.000000e+00
# 75%                0.000000e+00                   0.000000e+00
# max                8.000000e+00                   2.700000e+01
#
#        NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# count                  1.794331e+06               1.794331e+06
# mean                   7.256186e-04               2.748991e-02
# std                    2.744008e-02               1.653364e-01
# min                    0.000000e+00               0.000000e+00
# 25%                    0.000000e+00               0.000000e+00
# 50%                    0.000000e+00               0.000000e+00
# 75%                    0.000000e+00               0.000000e+00
# max                    6.000000e+00               4.000000e+00
#
#        NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  \
# count              1.794331e+06                1.794331e+06
# mean               1.097902e-04                2.155561e-01
# std                1.053057e-02                6.501723e-01
# min                0.000000e+00                0.000000e+00
# 25%                0.000000e+00                0.000000e+00
# 50%                0.000000e+00                0.000000e+00
# 75%                0.000000e+00                0.000000e+00
# max                2.000000e+00                4.300000e+01
#
#        NUMBER OF MOTORIST KILLED  COLLISION_ID
# count               1.794331e+06  1.794331e+06
# mean                5.667851e-04  3.156338e+06
# std                 2.616513e-02  1.499484e+06
# min                 0.000000e+00  2.200000e+01
# 25%                 0.000000e+00  3.168060e+06
# 50%                 0.000000e+00  3.690412e+06
# 75%                 0.000000e+00  4.172828e+06
# max                 5.000000e+00  4.661281e+06

# %% [markdown]
# - 25%, 50% (the median), and 75% percentiles are all 0, but the mean and max are greater than 0, it indicates that a significant majority of the values in that column are zeros, but there are some non-zero values present which affect the mean and max.
# -  The non-zero values in these columns could be outliers or rare occurrences. For instance, in the context of this data, columns like NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS KILLED, etc., having a majority of zeros makes intuitive sense because, fortunately, most motor vehicle collisions might not result in fatalities.
# -  The data in these columns is heavily skewed. In this case, it's right-skewed, meaning there are a few large values that pull the mean to the right of the median.

# %% [markdown]
# removing Longitude Values that are not from NY:

# %%
df.drop(df[df['LATITUDE'] < 39].index, inplace=True)

# %%
df.drop(df[df['LATITUDE'] > 41].index, inplace=True)

# %%
df.drop(df[df['LONGITUDE'] > -69].index, inplace=True)

# %%
df.drop(df[df['LONGITUDE'] < -74.5].index, inplace=True)

# %%
df[['LATITUDE', 'LONGITUDE']].describe()
# Out:
#            LATITUDE     LONGITUDE
# count  1.789953e+06  1.789953e+06
# mean   4.072419e+01 -7.392016e+01
# std    7.905826e-02  8.605679e-02
# min    4.049895e+01 -7.474200e+01
# 25%    4.066837e+01 -7.397495e+01
# 50%    4.072125e+01 -7.392750e+01
# 75%    4.076975e+01 -7.386719e+01
# max    4.134796e+01 -7.366301e+01

# %%
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'LATITUDE'}>,
#         <AxesSubplot:title={'center':'LONGITUDE'}>,
#         <AxesSubplot:title={'center':'NUMBER OF PERSONS INJURED'}>],
#        [<AxesSubplot:title={'center':'NUMBER OF PERSONS KILLED'}>,
#         <AxesSubplot:title={'center':'NUMBER OF PEDESTRIANS INJURED'}>,
#         <AxesSubplot:title={'center':'NUMBER OF PEDESTRIANS KILLED'}>],
#        [<AxesSubplot:title={'center':'NUMBER OF CYCLIST INJURED'}>,
#         <AxesSubplot:title={'center':'NUMBER OF CYCLIST KILLED'}>,
#         <AxesSubplot:title={'center':'NUMBER OF MOTORIST INJURED'}>],
#        [<AxesSubplot:title={'center':'NUMBER OF MOTORIST KILLED'}>,
#         <AxesSubplot:title={'center':'COLLISION_ID'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# The histograms from above are skewed to right, this could make harder for machine learning models to detect patterns;
# - therefore, I have to transform these attributes to have a more bell-shaped distributions.

# %% [markdown]
# ### Create a Test Set

# %% [markdown]
# Large datasets can be cumbersome to process, especially on standard personal computers. A well-chosen representative subset can significantly speed up computations, making preliminary analyses faster and more interactive.
#
# By working with a smaller, but representative subset, you can better understand the distributions, relationships, and potential anomalies in your data without getting overwhelmed.
#
# Not all systems have the capacity to handle large datasets. By sampling a representative subset, you can still perform meaningful analyses without the need for specialized big data tools or infrastructure.
#
# A **stratified sample** is a sampling method used to produce a sample that is representative of the population across certain categories or groups.
#
# Let's operate under the premise that the **Borough** attribute plays a crucial role in creating a stratified sample which accurately represents the 'Motor Vehicle Collisions - Crashes' data.

# %%
# dropping NA values from data to prepare for stratification 
df.dropna(subset=['BOROUGH'], inplace=True)

# %%
df["BOROUGH"].value_counts()
# Out:
# BROOKLYN         431536
# QUEENS           364336
# MANHATTAN        303744
# BRONX            198768
# STATEN ISLAND     56740
# Name: BOROUGH, dtype: int64

# %%
df["BOROUGH"].hist()
# Out:
# <AxesSubplot:>

# %%
df["BOROUGH"].value_counts() / len(df)
# Out:
# BROOKLYN         0.318448
# QUEENS           0.268858
# MANHATTAN        0.224145
# BRONX            0.146679
# STATEN ISLAND    0.041871
# Name: BOROUGH, dtype: float64

# %%
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import train_test_split

# %%
# reset_index(drop=True), you reset the index of your DataFrame without adding a new column. This should ensure that the 
# indices provided by StratifiedShuffleSplit correspond to the actual indices of your DataFrame.
df = df.reset_index(drop=True)

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in split.split(df, df["BOROUGH"]):
    strat_train_set = df.loc[train_index]
    strat_test_set = df.loc[test_index]

# %%
def borough_cat_proportions(data):
    return data["BOROUGH"].value_counts() / len(data)

# random test dataset
train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)

# compare proportions:
compare_props = pd.DataFrame({
    "Full Data Set": borough_cat_proportions(df),
    "Stratified": borough_cat_proportions(strat_test_set),
    "Random": borough_cat_proportions(test_set),
}).sort_index()

compare_props
# Out:
#                Full Data Set  Stratified    Random
# BRONX               0.146679    0.146680  0.146677
# BROOKLYN            0.318448    0.318447  0.318720
# MANHATTAN           0.224145    0.224145  0.222931
# QUEENS              0.268858    0.268857  0.269543
# STATEN ISLAND       0.041871    0.041871  0.042129

# %% [markdown]
# While both the stratified and random samples exhibit similar proportions, I'll opt for the stratified sample to err on the side of caution.

# %%
compare_props["Rand. %error"] = 100 * compare_props["Random"] / compare_props["Full Data Set"] - 100
compare_props["Strat. %error"] = 100 * compare_props["Stratified"] / compare_props["Full Data Set"] - 100

compare_props
# Out:
#                Full Data Set  Stratified    Random  Rand. %error  \
# BRONX               0.146679    0.146680  0.146677     -0.001583
# BROOKLYN            0.318448    0.318447  0.318720      0.085435
# MANHATTAN           0.224145    0.224145  0.222931     -0.541319
# QUEENS              0.268858    0.268857  0.269543      0.254910
# STATEN ISLAND       0.041871    0.041871  0.042129      0.616775
#
#                Strat. %error
# BRONX               0.000932
# BROOKLYN           -0.000306
# MANHATTAN           0.000255
# QUEENS             -0.000348
# STATEN ISLAND      -0.000074

# %%
df = strat_train_set.copy()

# %%
df.plot(kind="scatter", x="LONGITUDE", y="LATITUDE")
# Out:
# <AxesSubplot:xlabel='LONGITUDE', ylabel='LATITUDE'>

# %%
df[df["BOROUGH"] == 'BRONX'].plot(kind="scatter", x="LONGITUDE", y="LATITUDE", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='LONGITUDE', ylabel='LATITUDE'>

# %%
df[df["BOROUGH"] == 'BROOKLYN'].plot(kind="scatter", x="LONGITUDE", y="LATITUDE", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='LONGITUDE', ylabel='LATITUDE'>

# %%
df[df["BOROUGH"] == 'MANHATTAN'].plot(kind="scatter", x="LONGITUDE", y="LATITUDE", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='LONGITUDE', ylabel='LATITUDE'>

# %%
df[df["BOROUGH"] == 'QUEENS'].plot(kind="scatter", x="LONGITUDE", y="LATITUDE", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='LONGITUDE', ylabel='LATITUDE'>

# %%
df[df["BOROUGH"] == 'STATEN ISLAND'].plot(kind="scatter", x="LONGITUDE", y="LATITUDE", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='LONGITUDE', ylabel='LATITUDE'>

# %% [markdown]
# Notices that the boroughs have data points that do not align with their expected geographical coordinates.

# %% [markdown]
# ### Removing Outliers

# %%
from sklearn.cluster import DBSCAN
from sklearn.ensemble import RandomForestClassifier

# %%
bronx = df[df["BOROUGH"] == 'BRONX'].copy()
brooklyn = df[df["BOROUGH"] == 'BROOKLYN'].copy()
manhattan = df[df["BOROUGH"] == 'MANHATTAN'].copy()
queens = df[df["BOROUGH"] == 'QUEENS'].copy()
statenIs = df[df["BOROUGH"] == 'STATEN ISLAND'].copy()

# %%
def rmNoise(borought, noise='rm', fr=0.5):
    data = borought.sample(frac=fr, random_state=42)
    coords = data[['LATITUDE', 'LONGITUDE']].values
    db = DBSCAN(eps=0.002, min_samples=50).fit(coords)  # you might need to adjust eps and min_samples
    data['labels'] = db.labels_
     
    if noise == 'rm':
        df_filtered = data[data['labels'] != -1]  # -1 indicates noise in DBSCAN
        return(df_filtered)

    else:
        data['is_outlier'] = (data['labels'] == -1).astype(int)    
        return(data)

# %%
def rmOutliers(newData, fullData):
    X_train = newData[['LATITUDE', 'LONGITUDE']]
    y_train = newData['is_outlier']
    
    clf = RandomForestClassifier(random_state=42)
    clf.fit(X_train, y_train)

    new_data_predictions = clf.predict(fullData[['LATITUDE', 'LONGITUDE']])
    
    fullData['is_outlier'] = new_data_predictions

    return(fullData[fullData['is_outlier'] == 0])

# %%
newBrooklyn = rmNoise(brooklyn, noise='data', fr=0.3)

# %%
brooklynClean = rmOutliers(newBrooklyn, brooklyn)

# %%
brooklynClean.plot(kind="scatter", x="LONGITUDE", y="LATITUDE", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='LONGITUDE', ylabel='LATITUDE'>

# %%
newBronx = rmNoise(bronx, noise='data', fr=0.7)

# %%
bronxClean = rmOutliers(newBronx, bronx)

# %%
bronxClean.plot(kind="scatter", x="LONGITUDE", y="LATITUDE", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='LONGITUDE', ylabel='LATITUDE'>

# %%
newManhattan = rmNoise(manhattan, noise='data', fr=0.3)

# %%
manhattanClean = rmOutliers(newManhattan, manhattan)

# %%
manhattanClean.plot(kind="scatter", x="LONGITUDE", y="LATITUDE", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='LONGITUDE', ylabel='LATITUDE'>

# %%
newQueens = rmNoise(queens, noise='data', fr=0.5)

# %%
queensClean = rmOutliers(newQueens, queens)

# %%
queensClean.plot(kind="scatter", x="LONGITUDE", y="LATITUDE", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='LONGITUDE', ylabel='LATITUDE'>

# %%
newStatenIs = rmNoise(statenIs, noise='data', fr=1)

# %%
statenIsClean = rmOutliers(newStatenIs, statenIs)

# %%
statenIsClean.plot(kind="scatter", x="LONGITUDE", y="LATITUDE", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='LONGITUDE', ylabel='LATITUDE'>

# %% [markdown]
# ### Saving New Data set

# %%
# Concatenate dataframes
frames = [brooklynClean, bronxClean, manhattanClean, queensClean, statenIsClean]
result = pd.concat(frames)

# Sort by date column (assuming the date column is named 'date')
result = result.sort_values(by=['CRASH DATE', 'CRASH TIME'])

# Reset index
result.reset_index(drop=True, inplace=True)

# Save to CSV in a 'data' folder in the same directory as the python script
result.to_csv('data/result.csv', index=False)

# %%
df = pd.read_csv("data/result.csv")
df.head()
# Out:
# /var/folders/k2/4pwm8g2x5nv53jx5sr5l010c0000gq/T/ipykernel_3173/931430867.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/result.csv")
#    CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  01/01/2013       0:01     QUEENS    11369  40.761609 -73.882678
# 1  01/01/2013       0:07  MANHATTAN    10002  40.720968 -73.982168
# 2  01/01/2013       0:20  MANHATTAN    10075  40.772074 -73.949939
# 3  01/01/2013       0:25     QUEENS    11419  40.683430 -73.826601
# 4  01/01/2013       0:30     QUEENS    11354  40.765363 -73.827865
#
#                     LOCATION                    ON STREET NAME  \
# 0  (40.7616085, -73.8826782)  86 STREET
# 1  (40.7209677, -73.9821677)  EAST HOUSTON STREET
# 2  (40.7720736, -73.9499388)  EAST 80 STREET
# 3    (40.68343, -73.8266015)  115 STREET
# 4  (40.7653631, -73.8278647)  35 AVENUE
#
#                   CROSS STREET NAME OFF STREET NAME  ...  \
# 0  30 AVENUE                                    NaN  ...
# 1  RIDGE STREET                                 NaN  ...
# 2  YORK AVENUE                                  NaN  ...
# 3  107 AVENUE                                   NaN  ...
# 4  UNION STREET                                 NaN  ...
#
#    CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN                            NaN        281035
# 1                            NaN                            NaN         12712
# 2                            NaN                            NaN         47038
# 3                    Unspecified                            NaN        229479
# 4                            NaN                            NaN        248344
#
#    VEHICLE TYPE CODE 1            VEHICLE TYPE CODE 2  \
# 0    PASSENGER VEHICLE  SPORT UTILITY / STATION WAGON
# 1                 TAXI              PASSENGER VEHICLE
# 2                 TAXI                           TAXI
# 3              UNKNOWN              PASSENGER VEHICLE
# 4    PASSENGER VEHICLE                            NaN
#
#              VEHICLE TYPE CODE 3  VEHICLE TYPE CODE 4  VEHICLE TYPE CODE 5  \
# 0                            NaN                  NaN                  NaN
# 1                            NaN                  NaN                  NaN
# 2                            NaN                  NaN                  NaN
# 3  SPORT UTILITY / STATION WAGON    PASSENGER VEHICLE                  NaN
# 4                            NaN                  NaN                  NaN
#
#   is_outlier labels
# 0          0    NaN
# 1          0    NaN
# 2          0    NaN
# 3          0    NaN
# 4          0    NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Handling Missing Values

# %%
def not_integer(value):
    try:
        float(value)
        return False
    except ValueError:
        return True

# Find values that can't be converted to an integer
non_int_values = df[df['ZIP CODE'].apply(not_integer)]
non_int_values
# Out:
#          CRASH DATE CRASH TIME BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 12885    01/06/2015      13:25  QUEENS           40.720103 -73.790376
# 62560    01/24/2013       7:00  QUEENS           40.720103 -73.790376
# 75989    01/29/2013      17:30  QUEENS           40.720103 -73.790376
# 97057    02/05/2015      19:10  QUEENS           40.720103 -73.790376
# 151178   02/25/2014      16:30  QUEENS           40.720103 -73.790376
# 202326   03/15/2013      16:15  QUEENS           40.720103 -73.790376
# 205189   03/16/2014      10:30  QUEENS           40.720103 -73.790376
# 215306   03/20/2013       8:29  QUEENS           40.720103 -73.790376
# 225409   03/24/2014      12:05  QUEENS           40.720103 -73.790376
# 242340   03/31/2014      20:33  QUEENS           40.724794 -73.722910
# 319986   05/02/2013       8:00  QUEENS           40.720103 -73.790376
# 330943   05/06/2014      12:30  QUEENS           40.724794 -73.722910
# 395506   05/28/2014      14:50  QUEENS           40.724794 -73.722910
# 407227   06/01/2014      16:08  QUEENS           40.720103 -73.790376
# 457795   06/18/2014      15:10  QUEENS           40.720103 -73.790376
# 554539   07/19/2012      16:25  QUEENS           40.720103 -73.790376
# 558071   07/20/2012       9:00  QUEENS           40.720103 -73.790376
# 600349   08/02/2014      16:30  QUEENS           40.720103 -73.790376
# 656030   08/20/2013      12:15  QUEENS           40.720103 -73.790376
# 665498   08/23/2014      11:20  QUEENS           40.720103 -73.790376
# 701384   09/04/2013      15:55  QUEENS           40.724794 -73.722910
# 727485   09/12/2014       9:30  QUEENS           40.720103 -73.790376
# 739665   09/16/2013       8:24  QUEENS           40.720103 -73.790376
# 795140   10/04/2014      20:55  QUEENS           40.720103 -73.790376
# 803340   10/07/2012      20:00  QUEENS           40.724794 -73.722910
# 870257   10/29/2014      18:11  QUEENS           40.720103 -73.790376
# 937617   11/20/2013      15:20  QUEENS           40.720103 -73.790376
# 978160   12/04/2012      22:35  QUEENS           40.724794 -73.722910
# 994044   12/09/2013       8:10  QUEENS           40.720103 -73.790376
# 996502   12/10/2012      11:30  QUEENS           40.724794 -73.722910
# 1003357  12/12/2013       8:15  QUEENS           40.724794 -73.722910
#
#                          LOCATION                    ON STREET NAME  \
# 12885    (40.720103, -73.7903765)  UTOPIA PARKWAY
# 62560    (40.720103, -73.7903765)  UTOPIA PARKWAY
# 75989    (40.720103, -73.7903765)  UTOPIA PARKWAY
# 97057    (40.720103, -73.7903765)  UTOPIA PARKWAY
# 151178   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 202326   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 205189   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 215306   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 225409   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 242340   (40.724794, -73.7229102)  JAMAICA AVENUE
# 319986   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 330943   (40.724794, -73.7229102)  245 STREET
# 395506   (40.724794, -73.7229102)  245 STREET
# 407227   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 457795   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 554539   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 558071   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 600349   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 656030   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 665498   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 701384   (40.724794, -73.7229102)  JAMAICA AVENUE
# 727485   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 739665   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 795140   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 803340   (40.724794, -73.7229102)  JAMAICA AVENUE
# 870257   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 937617   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 978160   (40.724794, -73.7229102)  245 STREET
# 994044   (40.720103, -73.7903765)  UTOPIA PARKWAY
# 996502   (40.724794, -73.7229102)  245 STREET
# 1003357  (40.724794, -73.7229102)  JAMAICA AVENUE
#
#                         CROSS STREET NAME OFF STREET NAME  ...  \
# 12885    GRAND CENTRAL PARKWAY                        NaN  ...
# 62560    GRAND CENTRAL PARKWAY                        NaN  ...
# 75989    GRAND CENTRAL PARKWAY                        NaN  ...
# 97057    GRAND CENTRAL PARKWAY                        NaN  ...
# 151178   GRAND CENTRAL PARKWAY                        NaN  ...
# 202326   GRAND CENTRAL PARKWAY                        NaN  ...
# 205189   GRAND CENTRAL PARKWAY                        NaN  ...
# 215306   GRAND CENTRAL PARKWAY                        NaN  ...
# 225409   GRAND CENTRAL PARKWAY                        NaN  ...
# 242340   245 STREET                                   NaN  ...
# 319986   GRAND CENTRAL PARKWAY                        NaN  ...
# 330943   JAMAICA AVENUE                               NaN  ...
# 395506   JAMAICA AVENUE                               NaN  ...
# 407227   GRAND CENTRAL PARKWAY                        NaN  ...
# 457795   GRAND CENTRAL PARKWAY                        NaN  ...
# 554539   GRAND CENTRAL PARKWAY                        NaN  ...
# 558071   GRAND CENTRAL PARKWAY                        NaN  ...
# 600349   GRAND CENTRAL PARKWAY                        NaN  ...
# 656030   GRAND CENTRAL PARKWAY                        NaN  ...
# 665498   GRAND CENTRAL PARKWAY                        NaN  ...
# 701384   245 STREET                                   NaN  ...
# 727485   GRAND CENTRAL PARKWAY                        NaN  ...
# 739665   GRAND CENTRAL PARKWAY                        NaN  ...
# 795140   GRAND CENTRAL PARKWAY                        NaN  ...
# 803340   245 STREET                                   NaN  ...
# 870257   GRAND CENTRAL PARKWAY                        NaN  ...
# 937617   GRAND CENTRAL PARKWAY                        NaN  ...
# 978160   JAMAICA AVENUE                               NaN  ...
# 994044   GRAND CENTRAL PARKWAY                        NaN  ...
# 996502   JAMAICA AVENUE                               NaN  ...
# 1003357  245 STREET                                   NaN  ...
#
#          CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# 12885                              NaN                            NaN
# 62560                              NaN                            NaN
# 75989                              NaN                            NaN
# 97057                              NaN                            NaN
# 151178                             NaN                            NaN
# 202326                             NaN                            NaN
# 205189                             NaN                            NaN
# 215306                             NaN                            NaN
# 225409                             NaN                            NaN
# 242340                             NaN                            NaN
# 319986                             NaN                            NaN
# 330943                             NaN                            NaN
# 395506                             NaN                            NaN
# 407227                             NaN                            NaN
# 457795                             NaN                            NaN
# 554539                             NaN                            NaN
# 558071                             NaN                            NaN
# 600349                             NaN                            NaN
# 656030                             NaN                            NaN
# 665498                             NaN                            NaN
# 701384                             NaN                            NaN
# 727485                             NaN                            NaN
# 739665                             NaN                            NaN
# 795140                             NaN                            NaN
# 803340                             NaN                            NaN
# 870257                             NaN                            NaN
# 937617                             NaN                            NaN
# 978160                             NaN                            NaN
# 994044                             NaN                            NaN
# 996502                             NaN                            NaN
# 1003357                            NaN                            NaN
#
#          COLLISION_ID            VEHICLE TYPE CODE 1  \
# 12885         3148436              PASSENGER VEHICLE
# 62560          234809              PASSENGER VEHICLE
# 75989          234865  SPORT UTILITY / STATION WAGON
# 97057         3165171              PASSENGER VEHICLE
# 151178         238539              PASSENGER VEHICLE
# 202326         235253              PASSENGER VEHICLE
# 205189         306960              PASSENGER VEHICLE
# 215306         235289  SPORT UTILITY / STATION WAGON
# 225409         310902              PASSENGER VEHICLE
# 242340         313775              PASSENGER VEHICLE
# 319986         235647              PASSENGER VEHICLE
# 330943         331113  SPORT UTILITY / STATION WAGON
# 395506         342468              PASSENGER VEHICLE
# 407227         345139  SPORT UTILITY / STATION WAGON
# 457795         354381              PASSENGER VEHICLE
# 554539         233280              PASSENGER VEHICLE
# 558071         233281              PASSENGER VEHICLE
# 600349        1003064  SPORT UTILITY / STATION WAGON
# 656030         236595                        UNKNOWN
# 665498        1012787              PASSENGER VEHICLE
# 701384         225184              PASSENGER VEHICLE
# 727485        1022975              PASSENGER VEHICLE
# 739665         236835                        UNKNOWN
# 795140        1034164  SPORT UTILITY / STATION WAGON
# 803340         220751              PASSENGER VEHICLE
# 870257        2816421  SPORT UTILITY / STATION WAGON
# 937617         237545              PASSENGER VEHICLE
# 978160         221511              PASSENGER VEHICLE
# 994044         237752              PASSENGER VEHICLE
# 996502         221612                  PICK-UP TRUCK
# 1003357        226683              PASSENGER VEHICLE
#
#                    VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3  \
# 12885                PASSENGER VEHICLE                  NaN
# 62560    SPORT UTILITY / STATION WAGON                  NaN
# 75989    SPORT UTILITY / STATION WAGON                  NaN
# 97057    SPORT UTILITY / STATION WAGON                  NaN
# 151178   SPORT UTILITY / STATION WAGON                  NaN
# 202326               PASSENGER VEHICLE                  NaN
# 205189               PASSENGER VEHICLE                  NaN
# 215306               PASSENGER VEHICLE                  NaN
# 225409                            TAXI                  NaN
# 242340               PASSENGER VEHICLE                  NaN
# 319986               PASSENGER VEHICLE                  NaN
# 330943               PASSENGER VEHICLE                  NaN
# 395506                             NaN                  NaN
# 407227               PASSENGER VEHICLE                  NaN
# 457795   SPORT UTILITY / STATION WAGON                  NaN
# 554539               PASSENGER VEHICLE                  NaN
# 558071               PASSENGER VEHICLE                  NaN
# 600349   SPORT UTILITY / STATION WAGON                  NaN
# 656030   SPORT UTILITY / STATION WAGON                  NaN
# 665498                             VAN                  NaN
# 701384                         UNKNOWN                  NaN
# 727485               PASSENGER VEHICLE                  NaN
# 739665               PASSENGER VEHICLE                  NaN
# 795140   SPORT UTILITY / STATION WAGON                  NaN
# 803340               PASSENGER VEHICLE                  NaN
# 870257   SPORT UTILITY / STATION WAGON                  NaN
# 937617               PASSENGER VEHICLE                  NaN
# 978160   SPORT UTILITY / STATION WAGON                  NaN
# 994044               PASSENGER VEHICLE                  NaN
# 996502                             NaN                  NaN
# 1003357  SPORT UTILITY / STATION WAGON                  NaN
#
#          VEHICLE TYPE CODE 4  VEHICLE TYPE CODE 5 is_outlier labels
# 12885                    NaN                  NaN          0    NaN
# 62560                    NaN                  NaN          0    NaN
# 75989                    NaN                  NaN          0    NaN
# 97057                    NaN                  NaN          0    NaN
# 151178                   NaN                  NaN          0    NaN
# 202326                   NaN                  NaN          0    NaN
# 205189                   NaN                  NaN          0    NaN
# 215306                   NaN                  NaN          0    NaN
# 225409                   NaN                  NaN          0    NaN
# 242340                   NaN                  NaN          0    NaN
# 319986                   NaN                  NaN          0    NaN
# 330943                   NaN                  NaN          0    NaN
# 395506                   NaN                  NaN          0    NaN
# 407227                   NaN                  NaN          0    NaN
# 457795                   NaN                  NaN          0    NaN
# 554539                   NaN                  NaN          0    NaN
# 558071                   NaN                  NaN          0    NaN
# 600349                   NaN                  NaN          0    NaN
# 656030                   NaN                  NaN          0    NaN
# 665498                   NaN                  NaN          0    NaN
# 701384                   NaN                  NaN          0    NaN
# 727485                   NaN                  NaN          0    NaN
# 739665                   NaN                  NaN          0    NaN
# 795140                   NaN                  NaN          0    NaN
# 803340                   NaN                  NaN          0    NaN
# 870257                   NaN                  NaN          0    NaN
# 937617                   NaN                  NaN          0    NaN
# 978160                   NaN                  NaN          0    NaN
# 994044                   NaN                  NaN          0    NaN
# 996502                   NaN                  NaN          0    NaN
# 1003357                  NaN                  NaN          0    NaN
#
# [31 rows x 31 columns]

# %%
df['ZIP CODE'] = pd.to_numeric(df['ZIP CODE'], errors='coerce')

non_int_values = df[df['ZIP CODE'].apply(not_integer)]
non_int_values
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, CONTRIBUTING FACTOR VEHICLE 1, CONTRIBUTING FACTOR VEHICLE 2, CONTRIBUTING FACTOR VEHICLE 3, CONTRIBUTING FACTOR VEHICLE 4, CONTRIBUTING FACTOR VEHICLE 5, COLLISION_ID, VEHICLE TYPE CODE 1, VEHICLE TYPE CODE 2, VEHICLE TYPE CODE 3, VEHICLE TYPE CODE 4, VEHICLE TYPE CODE 5, is_outlier, labels]
# Index: []
#
# [0 rows x 31 columns]

# %%
empty_or_nan_rows = df[df['ZIP CODE'].isna() | (df['ZIP CODE'] == '')]
empty_or_nan_rows
# Out:
#          CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 9016     01/04/2019      19:00     QUEENS       NaN  40.720100 -73.790380
# 12885    01/06/2015      13:25     QUEENS       NaN  40.720103 -73.790376
# 13757    01/06/2017      23:00  MANHATTAN       NaN  40.736770 -73.974420
# 17341    01/07/2021      12:48     QUEENS       NaN  40.720100 -73.790380
# 30442    01/12/2017      14:45     QUEENS       NaN  40.720100 -73.790380
# ...             ...        ...        ...       ...        ...        ...
# 1020314  12/17/2016      11:15     QUEENS       NaN  40.724792 -73.722916
# 1027466  12/19/2017       8:30  MANHATTAN       NaN  40.736700 -73.974464
# 1030184  12/20/2016      19:30     QUEENS       NaN  40.733120 -73.727900
# 1040264  12/23/2018       4:21     QUEENS       NaN  40.712120 -73.911026
# 1042819  12/24/2017      22:45     QUEENS       NaN  40.720100 -73.790380
#
#                          LOCATION                    ON STREET NAME  \
# 9016         (40.7201, -73.79038)  UTOPIA PARKWAY
# 12885    (40.720103, -73.7903765)  UTOPIA PARKWAY
# 13757       (40.73677, -73.97442)                               NaN
# 17341        (40.7201, -73.79038)  UTOPIA PARKWAY
# 30442        (40.7201, -73.79038)  UTOPIA PARKWAY
# ...                           ...                               ...
# 1020314   (40.724792, -73.722916)  JAMAICA AVENUE
# 1027466     (40.7367, -73.974464)                               NaN
# 1030184      (40.73312, -73.7279)                               NaN
# 1040264    (40.71212, -73.911026)                               NaN
# 1042819      (40.7201, -73.79038)  GRAND CENTRAL PARKWAY
#
#                         CROSS STREET NAME  \
# 9016                GRAND CENTRAL PARKWAY
# 12885    GRAND CENTRAL PARKWAY
# 13757                                 NaN
# 17341               GRAND CENTRAL PARKWAY
# 30442               GRAND CENTRAL PARKWAY
# ...                                   ...
# 1020314                        245 STREET
# 1027466                               NaN
# 1030184                               NaN
# 1040264                               NaN
# 1042819                    UTOPIA PARKWAY
#
#                                   OFF STREET NAME  ...  \
# 9016                                          NaN  ...
# 12885                                         NaN  ...
# 13757    24-50     FDR DRIVE                       ...
# 17341                                         NaN  ...
# 30442                                         NaN  ...
# ...                                           ...  ...
# 1020314                                       NaN  ...
# 1027466  2430      FDR DRIVE                       ...
# 1030184  238-10    HILLSIDE AVENUE                 ...
# 1040264  350       GRANDVIEW AVENUE                ...
# 1042819                                       NaN  ...
#
#          CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# 9016                               NaN                            NaN
# 12885                              NaN                            NaN
# 13757                              NaN                            NaN
# 17341                              NaN                            NaN
# 30442                              NaN                            NaN
# ...                                ...                            ...
# 1020314                            NaN                            NaN
# 1027466                            NaN                            NaN
# 1030184                            NaN                            NaN
# 1040264                            NaN                            NaN
# 1042819                            NaN                            NaN
#
#          COLLISION_ID                  VEHICLE TYPE CODE 1  \
# 9016          4061817                                Sedan
# 12885         3148436                    PASSENGER VEHICLE
# 13757         3593885  Station Wagon/Sport Utility Vehicle
# 17341         4382202                                Sedan
# 30442         3597099                                Sedan
# ...               ...                                  ...
# 1020314       3581339                                Sedan
# 1027466       4025360  Station Wagon/Sport Utility Vehicle
# 1030184       3583780                                Sedan
# 1040264       4050742                                Sedan
# 1042819       3815882                                Sedan
#
#                          VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3  \
# 9016     Station Wagon/Sport Utility Vehicle                  NaN
# 12885                      PASSENGER VEHICLE                  NaN
# 13757                                    NaN                  NaN
# 17341                                  Sedan                  NaN
# 30442                                  Sedan                  NaN
# ...                                      ...                  ...
# 1020314                                Sedan                  NaN
# 1027466                                  NaN                  NaN
# 1030184                                Sedan                  NaN
# 1040264                                Sedan                 Taxi
# 1042819                                  NaN                  NaN
#
#          VEHICLE TYPE CODE 4  VEHICLE TYPE CODE 5 is_outlier labels
# 9016                     NaN                  NaN          0    NaN
# 12885                    NaN                  NaN          0    NaN
# 13757                    NaN                  NaN          0    NaN
# 17341                    NaN                  NaN          0    NaN
# 30442                    NaN                  NaN          0    NaN
# ...                      ...                  ...        ...    ...
# 1020314                  NaN                  NaN          0    NaN
# 1027466                  NaN                  NaN          0    NaN
# 1030184                  NaN                  NaN          0    NaN
# 1040264                  NaN                  NaN          0    NaN
# 1042819                  NaN                  NaN          0    NaN
#
# [192 rows x 31 columns]

# %%
# Get the unique values from empty_or_nan_rows['LOCATION']
unique_locations = empty_or_nan_rows['LOCATION'].unique()

# Filter df based on whether df['LOCATION'] is in unique_locations
matched_rows = df[df['LOCATION'].isin(unique_locations)]

# Print the matched 'LOCATION' and 'ZIP CODE' columns
print(matched_rows[['LOCATION', 'ZIP CODE']])
# Out:
#                         LOCATION  ZIP CODE
# 1476      (40.763958, -73.82814)   11354.0
# 5989       (40.76536, -73.82787)   11354.0
# 9016        (40.7201, -73.79038)       NaN
# 11671    (40.724792, -73.722916)   11426.0
# 12091      (40.77064, -73.82658)   11354.0
# ...                          ...       ...
# 1045136    (40.76536, -73.82787)   11354.0
# 1051330   (40.763958, -73.82814)   11354.0
# 1054429   (40.763958, -73.82814)   11354.0
# 1056958   (40.763958, -73.82814)   11354.0
# 1059409   (40.763958, -73.82814)   11354.0
#
# [467 rows x 2 columns]
